# %%
import pandas as pd

# %% [markdown]
# ## Dofine path to table filed

# %%
w_restaurant_PATH = 'C:\\Users\\computer\\Desktop\\Work\\AJ.Ton\\w_restaurant.csv'
seach_click_PATH = 'C:\\Users\\computer\\Desktop\\Work\\AJ.Ton\\search_click.csv'

# %% [markdown]
# ## Lode files into memory

# %%
w_restaurant_df = pandas.read_csv(w_restaurant_PATH)
seach_click_df = pandas.read_csv(seach_click_PATH)

# %% [markdown]
# ## Look at the table (ดูที่เราLoadเข้าไป)

# %%
w_restaurant_df
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# ...        ...                                   ...        ...     ...
# 246842  340068                            Sushi Tama          1       0
# 246843  340070                     สะบายดี คาราโอเกะ          1       0
# 246844  340074                      สเต็กแม่&กาแฟลูก          1       0
# 246845  340079                              Mom Made          1       0
# 246846  340091  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %% [markdown]
# #### ดูแค่หัวตาราง

# %%
w_restaurant_df.head()
# Out:
#    id              name  domain_id  closed                    city_name  \
# 0   2  นครินทร์ทันตกรรม          2       0              Samut Songkhram
# 1   4      Corner House          1       0  Bangkok Metropolitan Region
# 2   5    วัดโลกยสุธาราม          4       0     Phra Nakhon Si Ayutthaya
# 3   6    นันท์คาราโอเกะ          1       0  Bangkok Metropolitan Region
# 4   7       Buono Caffe          1       0  Bangkok Metropolitan Region
#
#   zipcode  geohash  new_open  weighted_average_rating  number_of_chains  ...  \
# 0   75000  w4rh7g3         0                 5.000000               NaN  ...
# 1   12150  w4rx73h         0                 2.000000               NaN  ...
# 2   13000  w4x98jk         0                 4.000000               NaN  ...
# 3   10700  w4rqw9q         0                 0.000000               NaN  ...
# 4   10220  w4rx4gd         0                 3.738462               NaN  ...
#
#    good_for_groups  good_for_kids  bookable  best_of_wongnai  wifi  \
# ...

# %% [markdown]
# #### ดูหางตาราง

# %%
w_restaurant_df.tail()
# Out:
#             id                                  name  domain_id  closed  \
# 246842  340068                            Sushi Tama          1       0
# 246843  340070                     สะบายดี คาราโอเกะ          1       0
# 246844  340074                      สเต็กแม่&กาแฟลูก          1       0
# 246845  340079                              Mom Made          1       0
# 246846  340091  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง          1       0
#
#                           city_name zipcode  geohash  new_open  \
# 246842  Bangkok Metropolitan Region   11130  w4rqtcb         0
# 246843  Bangkok Metropolitan Region     NaN  w4rwjcg         0
# 246844  Bangkok Metropolitan Region   10160  w4rmvxf         0
# 246845          Nakhon Si Thammarat   80000  w1x04g6         0
# 246846                  Suphan Buri   72000  w4x4q7s         0
#
#         weighted_average_rating  number_of_chains  ...  good_for_groups  \
# 246842                 3.663522               3.0  ...              0.0
# ...

# %% [markdown]
# #### ดูขนาดของตาราง > ชื่อตัวแปร.shape

# %%
seach_click_df.shape
# Out:
# (1048575, 6)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ## Missing

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# ### แก้missing
# #### 1. Delete row with missing data

# %%
w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])
# Out:
#             id          name  domain_id  closed                    city_name  \
# 61         114      มานีมีนม          1       0  Bangkok Metropolitan Region
# 114        224  สเต็กลุงหนวด          1       0  Bangkok Metropolitan Region
# 115        225      Mr.shake          1       0  Bangkok Metropolitan Region
# 131        267           KFC          1       0  Bangkok Metropolitan Region
# 140        297    Miss Mamon          1       1  Bangkok Metropolitan Region
# ...        ...           ...        ...     ...                          ...
# 246722  339787  Chang coffee          1       0                   Chiang Mai
# 246752  339864      Hokkaido          1       0  Bangkok Metropolitan Region
# 246815  340000  สเต็กลุงหนวด          1       0                 Nakhon Sawan
# 246834  340048     Kuppadeli          1       1  Bangkok Metropolitan Region
# 246842  340068    Sushi Tama          1       0  Bangkok Metropolitan Region
#
# ...

# %%
w_restaurant_df = w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])

# %% [markdown]
# #### 2. Fill default value to the data

# %%
w_restaurant_df['parking'].fillna(0)
# Out:
# 61        3.0
# 114       3.0
# 115       0.0
# 131       3.0
# 140       3.0
#          ...
# 246722    1.0
# 246752    3.0
# 246815    3.0
# 246834    0.0
# 246842    3.0
# Name: parking, Length: 13669, dtype: float64

# %% [markdown]
# Updateบางfill

# %%
w_restaurant_df['parking'] = w_restaurant_df['parking'].fillna(0)
# Out:
# E:\Progam T.Ton\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### 3.select part of the table by value  การเลือกบางส่วนของตาราง
# part of table = table[data_condition == True]

# %%
w_restaurant_df['parking'] >= 3
# Out:
# 61         True
# 114        True
# 115       False
# 131        True
# 140        True
#           ...
# 246722    False
# 246752     True
# 246815     True
# 246834    False
# 246842     True
# Name: parking, Length: 13669, dtype: bool

# %%
w_restaurant_df[w_restaurant_df['parking'] >= 3]
# Out:
#             id                             name  domain_id  closed  \
# 61         114                         มานีมีนม          1       0
# 114        224                     สเต็กลุงหนวด          1       0
# 131        267                              KFC          1       0
# 140        297                       Miss Mamon          1       1
# 149        344                  Inthanin Coffee          1       0
# ...        ...                              ...        ...     ...
# 246646  339670  Four Seasons Chinese Restaurant          1       0
# 246684  339718                     Jeffer Steak          1       0
# 246752  339864                         Hokkaido          1       0
# 246815  340000                     สเต็กลุงหนวด          1       0
# 246842  340068                       Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# 61      Bangkok Metropolitan Region   10312  w4rw3e0         0
# ...

# %% [markdown]
# # Home work select all restaurant from your hometown

# %%
w_restaurant_df = pandas.read_csv(w_restaurant_PATH)

# %%
set(w_restaurant_df['city_name'])
# Out:
# {'Abu Dhabi',
#  'Aichi-ken',
#  'Akershus',
#  'Akita-ken',
#  'Al Farwaniyah Governorate',
#  'Alabama',
#  'Alaska',
#  'Alberta',
#  'Amnat Charoen',
#  'Andalucía',
#  'Ang Thong',
#  'Aomori-ken',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'Aragón',
#  'Argyll and Bute',
#  'Arizona',
#  'Attica',
#  'Auckland',
#  'Australia',
#  'Auvergne-Rhône-Alpes',
#  'Aydın',
#  'Ba Ria - Vung Tau',
#  'Baden-Wurttemberg',
#  'Bago Region',
#  'Bahia',
#  'Bali',
#  'Balochistan',
#  'Bangkok Metropolitan Region',
#  'Banteay Meanchey Province',
#  'Banten',
#  'Basel-Stadt',
#  'Basilicata',
#  'Basrah',
#  'Battambang',
#  'Bay Of Plenty',
#  'Bayern',
#  'Berlin',
#  'Bern',
#  'Bihar',
#  'Binh Thuan',
#  'Binh Thuan province',
#  'Borno',
#  'Bratislava',
#  'Bremen',
#  'Bretagne',
#  'British Columbia',
#  'Brussels Hoofdstedelijk Gewest',
#  'Buckinghamshire',
#  'Budapest',
#  'Bueng Kan',
#  'Buri Ram',
#  'Busan',
#  'Buskerud',
#  'C2 MALL',
#  'CALABARZON',
# ...

# %%
w_restaurant_df[w_restaurant_df['city_name'] == 'Khon Kaen']
# Out:
#             id                               name  domain_id  closed  \
# 81         149                        WISH CLINIC          2       0
# 317        614                           Pomodoro          1       0
# 390        710                         ครัวอรวรรณ          1       0
# 452        805                     วาสนาเคียมห้วย          1       0
# 514        885                        ส้มตำศิริพร          1       0
# ...        ...                                ...        ...     ...
# 246312  339286  สเวนเซ่นส์ เซ็นทรัลพลาซ่า ขอนแก่น          1       0
# 246335  339311                     คิดถึงเบเกอรี่          1       0
# 246638  339659                    Firehaus Bistro          1       0
# 246748  339857                        ร้านป้าจ่อย          1       0
# 246818  340011                            Coffman          1       0
#
#         city_name zipcode  geohash  new_open  weighted_average_rating  \
# ...

# %% [markdown]
# ## Save table to a file

# %%
w_restaurant_df.to_csv('test.csv')
